# %% [markdown]
# Based on GOOG’s price behavior, liquidity, and volatility profile, a moderate-to-aggressive allocation framework is appropriate depending on investor objectives:
#
# * #### Conservative Portfolios:
# Allocate 5–8% to GOOG. This provides exposure to a high-quality growth stock while limiting downside risk from volatility.
#
# * #### Balanced Portfolios:
# Allocate 10–15% to GOOG. This range captures long-term growth potential and liquidity advantages while maintaining diversification.
#
# * #### Growth / Aggressive Portfolios:
# Allocate 18–25% to GOOG. Suitable for investors with higher risk tolerance seeking capital appreciation and able to manage short-term price swings.
#
# * #### Active Trading Capital (separate sleeve):
# Allocate 3–7% specifically for short-term trading strategies (breakouts, gap trades, momentum plays), isolated from long-term holdings.
